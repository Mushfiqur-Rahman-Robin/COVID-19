# %%
import numpy as np
import pandas as pd
import folium

# %%
df= pd.read_csv('C:/Users/USER/Desktop/covid19_apr20.csv')
df.head()
# Out:
#     Latitude  Longitude         Location  I_number
# 0  23.777176  90.339452            Dhaka      1174
# 1  23.810500  90.337200  Dhaka(district)        42
# 2  23.999941  90.420273          Gazipur       269
# 3  24.433123  90.786568      Kishoreganj       146
# 4  23.239300  90.187000        Madaripur        25

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot')

# %%
df.columns = list(map(str, df.columns))
all(isinstance(column, str) for column in df.columns)
# Out:
# True

# %%
#df.set_index('Location', inplace=True)
#df.head()

# %%
df.drop(['Longitude','Latitude'], axis=1, inplace=True)
df.head()
# Out:
#           Location  I_number
# 0            Dhaka      1174
# 1  Dhaka(district)        42
# 2          Gazipur       269
# 3      Kishoreganj       146
# 4        Madaripur        25

# %%
location= df['Location'].to_list()

# %%
df.plot(kind='bar', width=0.8, figsize=(18,27))

bars= plt.bar(location,height=list_of_infected,width=0.4)

plt.xlabel('Location')# add to x-label to the plot
plt.ylabel('Number of affected')# add y-label to the plot
plt.title('Covid-19 in Bangladesh till April 20') # add title to the plot
for bar in bars:
    yval= bar.get_height()
    plt.text(bar.get_x(), yval + 2, yval)
plt.legend()
plt.show()
